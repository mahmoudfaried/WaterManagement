# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout,SimpleRNN, GRU, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

from collections import Counter
from imblearn.over_sampling import SMOTE

counter = Counter(y)
print(counter)


oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

counter = Counter(y)
print(counter)
print(y_train.shape)
print(x_train.shape)
# Out:
# Counter({0.0: 7084, 1.0: 909})
# Counter({1.0: 7084, 0.0: 7084})
# (11334, 1)
# (11334, 16, 1)

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
model = Sequential()
model.add(GRU(128, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))
# Out:
# 2022-10-31 18:12:28.917449: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:28.918462: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.097091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.098005: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.098881: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.099668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.101075: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-31 18:12:29.354097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.355065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.355852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.356581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.357335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:29.358165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.684734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.685700: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.686525: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.687330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.688127: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.688854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-10-31 18:12:32.692455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:12:32.693179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,
          y_train,
          epochs= 150,
          batch_size = 200,
          validation_split=0.2,
          callbacks=[early])
# Out:
# 2022-10-31 18:12:33.332809: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 46/46 [==============================] - 6s 56ms/step - loss: 0.7215 - accuracy: 0.5536 - val_loss: 0.6937 - val_accuracy: 0.4901
# Epoch 2/150
# 46/46 [==============================] - 3s 58ms/step - loss: 0.6593 - accuracy: 0.6129 - val_loss: 0.6933 - val_accuracy: 0.4901
# Epoch 3/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.5231 - accuracy: 0.7605 - val_loss: 0.6788 - val_accuracy: 0.5137
# Epoch 4/150
# 46/46 [==============================] - 2s 48ms/step - loss: 0.4511 - accuracy: 0.8158 - val_loss: 0.6634 - val_accuracy: 0.5798
# Epoch 5/150
# 46/46 [==============================] - 3s 55ms/step - loss: 0.4297 - accuracy: 0.8270 - val_loss: 0.6367 - val_accuracy: 0.6792
# Epoch 6/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.4232 - accuracy: 0.8280 - val_loss: 0.6206 - val_accuracy: 0.7681
# Epoch 7/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.4164 - accuracy: 0.8323 - val_loss: 0.5877 - val_accuracy: 0.8345
# Epoch 8/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.4076 - accuracy: 0.8355 - val_loss: 0.5615 - val_accuracy: 0.8288
# Epoch 9/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.4047 - accuracy: 0.8359 - val_loss: 0.5238 - val_accuracy: 0.8388
# Epoch 10/150
# 46/46 [==============================] - 2s 54ms/step - loss: 0.4008 - accuracy: 0.8374 - val_loss: 0.4906 - val_accuracy: 0.8420
# Epoch 11/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3957 - accuracy: 0.8386 - val_loss: 0.4317 - val_accuracy: 0.8449
# Epoch 12/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3941 - accuracy: 0.8401 - val_loss: 0.4403 - val_accuracy: 0.8459
# Epoch 13/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3928 - accuracy: 0.8390 - val_loss: 0.4202 - val_accuracy: 0.8471
# Epoch 14/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3876 - accuracy: 0.8419 - val_loss: 0.3864 - val_accuracy: 0.8441
# Epoch 15/150
# 46/46 [==============================] - 3s 67ms/step - loss: 0.3855 - accuracy: 0.8419 - val_loss: 0.3753 - val_accuracy: 0.8475
# Epoch 16/150
# 46/46 [==============================] - 3s 66ms/step - loss: 0.3850 - accuracy: 0.8423 - val_loss: 0.3955 - val_accuracy: 0.8424
# Epoch 17/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3871 - accuracy: 0.8419 - val_loss: 0.3812 - val_accuracy: 0.8475
# Epoch 18/150
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3832 - accuracy: 0.8423 - val_loss: 0.3679 - val_accuracy: 0.8480
# Epoch 19/150
# 46/46 [==============================] - 3s 56ms/step - loss: 0.3778 - accuracy: 0.8456 - val_loss: 0.3647 - val_accuracy: 0.8481
# Epoch 20/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3755 - accuracy: 0.8455 - val_loss: 0.3586 - val_accuracy: 0.8508
# Epoch 21/150
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3745 - accuracy: 0.8461 - val_loss: 0.3632 - val_accuracy: 0.8476
# Epoch 22/150
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3743 - accuracy: 0.8459 - val_loss: 0.3734 - val_accuracy: 0.8480
# Epoch 23/150
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3740 - accuracy: 0.8461 - val_loss: 0.3647 - val_accuracy: 0.8512
# Epoch 24/150
# 46/46 [==============================] - 3s 57ms/step - loss: 0.3720 - accuracy: 0.8469 - val_loss: 0.3541 - val_accuracy: 0.8501
# Epoch 25/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3654 - accuracy: 0.8495 - val_loss: 0.3489 - val_accuracy: 0.8520
# Epoch 26/150
# 46/46 [==============================] - 2s 48ms/step - loss: 0.3677 - accuracy: 0.8486 - val_loss: 0.3538 - val_accuracy: 0.8521
# Epoch 27/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3667 - accuracy: 0.8488 - val_loss: 0.3498 - val_accuracy: 0.8524
# Epoch 28/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3640 - accuracy: 0.8491 - val_loss: 0.3490 - val_accuracy: 0.8533
# Epoch 29/150
# 46/46 [==============================] - 3s 69ms/step - loss: 0.3625 - accuracy: 0.8506 - val_loss: 0.3545 - val_accuracy: 0.8524
# Epoch 30/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3628 - accuracy: 0.8503 - val_loss: 0.3516 - val_accuracy: 0.8526
# Epoch 31/150
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3624 - accuracy: 0.8505 - val_loss: 0.3714 - val_accuracy: 0.8458
# Epoch 32/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3597 - accuracy: 0.8511 - val_loss: 0.3501 - val_accuracy: 0.8552
# Epoch 33/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3578 - accuracy: 0.8519 - val_loss: 0.3459 - val_accuracy: 0.8540
# Epoch 34/150
# 46/46 [==============================] - 3s 55ms/step - loss: 0.3552 - accuracy: 0.8527 - val_loss: 0.3423 - val_accuracy: 0.8555
# Epoch 35/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3564 - accuracy: 0.8532 - val_loss: 0.3443 - val_accuracy: 0.8546
# Epoch 36/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.3555 - accuracy: 0.8533 - val_loss: 0.3601 - val_accuracy: 0.8540
# Epoch 37/150
# 46/46 [==============================] - 2s 48ms/step - loss: 0.3534 - accuracy: 0.8544 - val_loss: 0.3461 - val_accuracy: 0.8534
# Epoch 38/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3550 - accuracy: 0.8525 - val_loss: 0.3412 - val_accuracy: 0.8577
# Epoch 39/150
# 46/46 [==============================] - 3s 56ms/step - loss: 0.3497 - accuracy: 0.8549 - val_loss: 0.3504 - val_accuracy: 0.8547
# Epoch 40/150
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3485 - accuracy: 0.8557 - val_loss: 0.3398 - val_accuracy: 0.8551
# Epoch 41/150
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3468 - accuracy: 0.8570 - val_loss: 0.3387 - val_accuracy: 0.8562
# Epoch 42/150
# 46/46 [==============================] - 2s 46ms/step - loss: 0.3513 - accuracy: 0.8562 - val_loss: 0.3399 - val_accuracy: 0.8571
# Epoch 43/150
# 46/46 [==============================] - 3s 73ms/step - loss: 0.3463 - accuracy: 0.8566 - val_loss: 0.3430 - val_accuracy: 0.8569
# Epoch 00043: early stopping

# %%
evaluation=model.evaluate(x_test, y_test, verbose=1)
# Out:
# 89/89 [==============================] - 1s 6ms/step - loss: 0.3855 - accuracy: 0.8365

# %%
pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
