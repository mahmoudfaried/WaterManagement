# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout, SimpleRNN, Activation ,BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

from collections import Counter
from imblearn.over_sampling import SMOTE

counter = Counter(y)
print(counter)


oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

print(y_train.shape)
print(x_train.shape)
counter = Counter(y)
print(counter)
# Out:
# Counter({0.0: 7084, 1.0: 909})
# (11334, 1)
# (11334, 16, 1)
# Counter({1.0: 7084, 0.0: 7084})

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
model = Sequential()
model.add(SimpleRNN(64, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,
                    y_train,
                    epochs= 150,
                    batch_size = 200,          
                    validation_split=0.2,
                    callbacks=[early])
# Out:
# Epoch 1/150
# 46/46 [==============================] - 29s 589ms/step - loss: 0.7313 - accuracy: 0.5456 - val_loss: 0.6845 - val_accuracy: 0.5716
# Epoch 2/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.5858 - accuracy: 0.6961 - val_loss: 0.5219 - val_accuracy: 0.7907
# Epoch 3/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.4750 - accuracy: 0.8007 - val_loss: 0.4951 - val_accuracy: 0.8093
# Epoch 4/150
# 46/46 [==============================] - 1s 30ms/step - loss: 0.4451 - accuracy: 0.8185 - val_loss: 0.4940 - val_accuracy: 0.8100
# Epoch 5/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.4277 - accuracy: 0.8252 - val_loss: 0.4667 - val_accuracy: 0.8155
# Epoch 6/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.4178 - accuracy: 0.8287 - val_loss: 0.4453 - val_accuracy: 0.8188
# Epoch 7/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.4082 - accuracy: 0.8314 - val_loss: 0.4320 - val_accuracy: 0.8266
# Epoch 8/150
# 46/46 [==============================] - 1s 28ms/step - loss: 0.4039 - accuracy: 0.8326 - val_loss: 0.4157 - val_accuracy: 0.8272
# Epoch 9/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3950 - accuracy: 0.8366 - val_loss: 0.3983 - val_accuracy: 0.8369
# Epoch 10/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3944 - accuracy: 0.8374 - val_loss: 0.3808 - val_accuracy: 0.8409
# Epoch 11/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.3879 - accuracy: 0.8389 - val_loss: 0.3690 - val_accuracy: 0.8462
# Epoch 12/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3846 - accuracy: 0.8406 - val_loss: 0.3629 - val_accuracy: 0.8483
# Epoch 13/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3798 - accuracy: 0.8424 - val_loss: 0.3649 - val_accuracy: 0.8490
# Epoch 14/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3759 - accuracy: 0.8459 - val_loss: 0.3591 - val_accuracy: 0.8497
# Epoch 15/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3735 - accuracy: 0.8449 - val_loss: 0.3567 - val_accuracy: 0.8493
# Epoch 16/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3710 - accuracy: 0.8466 - val_loss: 0.3586 - val_accuracy: 0.8500
# Epoch 17/150
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3716 - accuracy: 0.8465 - val_loss: 0.3529 - val_accuracy: 0.8487
# Epoch 18/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.3704 - accuracy: 0.8464 - val_loss: 0.3675 - val_accuracy: 0.8467
# Epoch 19/150
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3656 - accuracy: 0.8491 - val_loss: 0.3506 - val_accuracy: 0.8537
# Epoch 20/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.3635 - accuracy: 0.8513 - val_loss: 0.3464 - val_accuracy: 0.8513
# Epoch 21/150
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3608 - accuracy: 0.8523 - val_loss: 0.3581 - val_accuracy: 0.8532
# Epoch 22/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3582 - accuracy: 0.8538 - val_loss: 0.3490 - val_accuracy: 0.8551
# Epoch 23/150
# 46/46 [==============================] - 1s 33ms/step - loss: 0.3552 - accuracy: 0.8551 - val_loss: 0.3519 - val_accuracy: 0.8573
# Epoch 24/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3544 - accuracy: 0.8553 - val_loss: 0.3457 - val_accuracy: 0.8574
# Epoch 25/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.3503 - accuracy: 0.8579 - val_loss: 0.3412 - val_accuracy: 0.8595
# Epoch 26/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3488 - accuracy: 0.8576 - val_loss: 0.3465 - val_accuracy: 0.8567
# Epoch 27/150
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3466 - accuracy: 0.8586 - val_loss: 0.3338 - val_accuracy: 0.8616
# Epoch 28/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3427 - accuracy: 0.8615 - val_loss: 0.3469 - val_accuracy: 0.8606
# Epoch 29/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3452 - accuracy: 0.8588 - val_loss: 0.3408 - val_accuracy: 0.8617
# Epoch 30/150
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3437 - accuracy: 0.8607 - val_loss: 0.3320 - val_accuracy: 0.8641
# Epoch 31/150
# 46/46 [==============================] - 2s 32ms/step - loss: 0.3435 - accuracy: 0.8599 - val_loss: 0.3481 - val_accuracy: 0.8586
# Epoch 32/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3386 - accuracy: 0.8628 - val_loss: 0.3348 - val_accuracy: 0.8661
# Epoch 33/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3348 - accuracy: 0.8643 - val_loss: 0.3300 - val_accuracy: 0.8658
# Epoch 34/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3400 - accuracy: 0.8615 - val_loss: 0.3373 - val_accuracy: 0.8630
# Epoch 35/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.3335 - accuracy: 0.8645 - val_loss: 0.3287 - val_accuracy: 0.8646
# Epoch 36/150
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3304 - accuracy: 0.8661 - val_loss: 0.3299 - val_accuracy: 0.8672
# Epoch 37/150
# 46/46 [==============================] - 2s 41ms/step - loss: 0.3307 - accuracy: 0.8659 - val_loss: 0.3266 - val_accuracy: 0.8682
# Epoch 38/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3330 - accuracy: 0.8656 - val_loss: 0.3266 - val_accuracy: 0.8677
# Epoch 39/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3290 - accuracy: 0.8674 - val_loss: 0.3289 - val_accuracy: 0.8653
# Epoch 40/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3278 - accuracy: 0.8672 - val_loss: 0.3234 - val_accuracy: 0.8695
# Epoch 41/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3255 - accuracy: 0.8689 - val_loss: 0.3222 - val_accuracy: 0.8702
# Epoch 42/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3265 - accuracy: 0.8683 - val_loss: 0.3275 - val_accuracy: 0.8664
# Epoch 43/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3260 - accuracy: 0.8689 - val_loss: 0.3271 - val_accuracy: 0.8648
# Epoch 44/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3294 - accuracy: 0.8669 - val_loss: 0.3221 - val_accuracy: 0.8708
# Epoch 45/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3228 - accuracy: 0.8707 - val_loss: 0.3276 - val_accuracy: 0.8696
# Epoch 46/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3220 - accuracy: 0.8708 - val_loss: 0.3190 - val_accuracy: 0.8721
# Epoch 47/150
# 46/46 [==============================] - 1s 27ms/step - loss: 0.3210 - accuracy: 0.8713 - val_loss: 0.3278 - val_accuracy: 0.8684
# Epoch 48/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3183 - accuracy: 0.8726 - val_loss: 0.3240 - val_accuracy: 0.8685
# Epoch 49/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3166 - accuracy: 0.8728 - val_loss: 0.3182 - val_accuracy: 0.8727
# Epoch 50/150
# 46/46 [==============================] - 2s 33ms/step - loss: 0.3150 - accuracy: 0.8734 - val_loss: 0.3195 - val_accuracy: 0.8711
# Epoch 51/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.3266 - accuracy: 0.8670 - val_loss: 0.3216 - val_accuracy: 0.8686
# Epoch 52/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3190 - accuracy: 0.8721 - val_loss: 0.3235 - val_accuracy: 0.8677
# Epoch 53/150
# 46/46 [==============================] - 1s 30ms/step - loss: 0.3149 - accuracy: 0.8743 - val_loss: 0.3204 - val_accuracy: 0.8729
# Epoch 54/150
# 46/46 [==============================] - 1s 31ms/step - loss: 0.3115 - accuracy: 0.8750 - val_loss: 0.3347 - val_accuracy: 0.8661
# Epoch 55/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3117 - accuracy: 0.8752 - val_loss: 0.3190 - val_accuracy: 0.8720
# Epoch 56/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.3112 - accuracy: 0.8756 - val_loss: 0.3216 - val_accuracy: 0.8719
# Epoch 57/150
# 46/46 [==============================] - 2s 35ms/step - loss: 0.3126 - accuracy: 0.8742 - val_loss: 0.3312 - val_accuracy: 0.8697
# Epoch 58/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3126 - accuracy: 0.8756 - val_loss: 0.3165 - val_accuracy: 0.8740
# Epoch 59/150
# 46/46 [==============================] - 2s 33ms/step - loss: 0.3119 - accuracy: 0.8747 - val_loss: 0.3326 - val_accuracy: 0.8673
# Epoch 60/150
# 46/46 [==============================] - 2s 34ms/step - loss: 0.3153 - accuracy: 0.8730 - val_loss: 0.3263 - val_accuracy: 0.8695
# Epoch 61/150
# 46/46 [==============================] - 1s 32ms/step - loss: 0.3074 - accuracy: 0.8776 - val_loss: 0.3198 - val_accuracy: 0.8732
# Epoch 62/150
# 46/46 [==============================] - 1s 29ms/step - loss: 0.3036 - accuracy: 0.8787 - val_loss: 0.3180 - val_accuracy: 0.8740
# Epoch 63/150
# 46/46 [==============================] - 2s 33ms/step - loss: 0.3068 - accuracy: 0.8770 - val_loss: 0.3241 - val_accuracy: 0.8673
# Epoch 00063: early stopping

# %%
evaluation=model.evaluate(x_test, y_test, verbose=1)
# Out:
# 89/89 [==============================] - 1s 7ms/step - loss: 0.3513 - accuracy: 0.8527

# %%
pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
from tensorflow.keras.models import save_model
save_model(model, "model.h5")
