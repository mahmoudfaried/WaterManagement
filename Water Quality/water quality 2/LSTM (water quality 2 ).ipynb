# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout, LSTM, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical

from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

from collections import Counter
from imblearn.over_sampling import SMOTE

counter = Counter(y)
print(counter)


oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

counter = Counter(y)
print(counter)
print(y_train.shape)
print(x_train.shape)
# Out:
# Counter({0.0: 7084, 1.0: 909})
# Counter({1.0: 7084, 0.0: 7084})
# (11334, 1)
# (11334, 16, 1)

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(16,1), activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))
# Out:
# 2022-10-31 18:08:45.358080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.359931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.660571: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.661768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.662824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.663837: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.666299: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-31 18:08:45.936246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.937518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.938306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.939077: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.939845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:45.940575: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.748343: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.749246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.749986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.750707: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.751439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.752142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-10-31 18:08:50.757611: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-31 18:08:50.758572: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,
          y_train,
          batch_size = 200,
          epochs= 150, 
          validation_split=0.2,
          callbacks=[early])
# Out:
# 2022-10-31 18:08:51.451265: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 46/46 [==============================] - 6s 51ms/step - loss: 0.6653 - accuracy: 0.6138 - val_loss: 0.6875 - val_accuracy: 0.6568
# Epoch 2/150
# 46/46 [==============================] - 2s 51ms/step - loss: 0.5351 - accuracy: 0.7466 - val_loss: 0.6735 - val_accuracy: 0.7706
# Epoch 3/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.4613 - accuracy: 0.8044 - val_loss: 0.6523 - val_accuracy: 0.8098
# Epoch 4/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.4401 - accuracy: 0.8176 - val_loss: 0.6427 - val_accuracy: 0.8126
# Epoch 5/150
# 46/46 [==============================] - 2s 47ms/step - loss: 0.4309 - accuracy: 0.8206 - val_loss: 0.6202 - val_accuracy: 0.8234
# Epoch 6/150
# 46/46 [==============================] - 2s 52ms/step - loss: 0.4274 - accuracy: 0.8224 - val_loss: 0.6001 - val_accuracy: 0.8207
# Epoch 7/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.4186 - accuracy: 0.8268 - val_loss: 0.5918 - val_accuracy: 0.8255
# Epoch 8/150
# 46/46 [==============================] - 2s 36ms/step - loss: 0.4187 - accuracy: 0.8265 - val_loss: 0.5589 - val_accuracy: 0.8266
# Epoch 9/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.4131 - accuracy: 0.8289 - val_loss: 0.5204 - val_accuracy: 0.8224
# Epoch 10/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.4067 - accuracy: 0.8320 - val_loss: 0.5161 - val_accuracy: 0.8285
# Epoch 11/150
# 46/46 [==============================] - 2s 37ms/step - loss: 0.4066 - accuracy: 0.8319 - val_loss: 0.4848 - val_accuracy: 0.8295
# Epoch 12/150
# 46/46 [==============================] - 2s 42ms/step - loss: 0.4001 - accuracy: 0.8336 - val_loss: 0.4474 - val_accuracy: 0.8264
# Epoch 13/150
# 46/46 [==============================] - 2s 43ms/step - loss: 0.4019 - accuracy: 0.8337 - val_loss: 0.4160 - val_accuracy: 0.8317
# Epoch 14/150
# 46/46 [==============================] - 2s 38ms/step - loss: 0.3951 - accuracy: 0.8361 - val_loss: 0.4019 - val_accuracy: 0.8349
# Epoch 15/150
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3926 - accuracy: 0.8371 - val_loss: 0.3947 - val_accuracy: 0.8336
# Epoch 16/150
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3949 - accuracy: 0.8359 - val_loss: 0.3868 - val_accuracy: 0.8336
# Epoch 17/150
# 46/46 [==============================] - 2s 39ms/step - loss: 0.3884 - accuracy: 0.8381 - val_loss: 0.3911 - val_accuracy: 0.8333
# Epoch 18/150
# 46/46 [==============================] - 2s 45ms/step - loss: 0.3892 - accuracy: 0.8375 - val_loss: 0.4012 - val_accuracy: 0.8322
# Epoch 19/150
# 46/46 [==============================] - 3s 58ms/step - loss: 0.3873 - accuracy: 0.8376 - val_loss: 0.3806 - val_accuracy: 0.8336
# Epoch 00019: early stopping

# %%
evaluation = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 89/89 [==============================] - 1s 9ms/step - loss: 0.3988 - accuracy: 0.8262

# %%
pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
