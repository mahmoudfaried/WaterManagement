# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPool1D, BatchNormalization, Dropout, LSTM, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.utils import to_categorical
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from imblearn import under_sampling,over_sampling
import lightgbm as lgb
from imblearn.over_sampling import SMOTE 


from cv2 import imread, resize

# %%
data = pd.read_csv('../input/water-quality/waterQuality1.csv')

data = data.drop('ammonia', axis = 1)
data = data.drop('flouride', axis = 1)
data = data.drop('selenium', axis = 1)
data = data.drop('uranium', axis = 1)

data = data[data['is_safe'] != '#NUM!']
data['is_safe'] = data['is_safe'].astype(int)

columns = dict(zip(list(range(data.shape[1])), data.columns.values.tolist()))
is_safe = data['is_safe']

data = pd.DataFrame(StandardScaler().fit_transform(data)).rename(columns = columns)
data['is_safe'] = is_safe
data = data.dropna()
data.head(6)
# Out:
#    aluminium   arsenic    barium   cadmium  chloramine  chromium    copper  \
# 0   0.777403 -0.480875  1.054205 -0.993241   -0.711941  2.152993 -0.973050
# 1   1.306945 -0.599632  1.432447 -1.131948    1.208552  1.598765 -0.223303
# 2   0.271572 -0.480875 -0.812340 -0.965499    0.803417  1.044536 -1.202564
# 3   0.548198 -0.480875  1.144654 -1.159690    1.968179 -0.802892  1.306793
# 4   0.200439 -0.520460 -1.124801 -1.020982    0.191820  1.635713 -0.361012
# 5   0.216246 -0.520460  1.078873 -1.104207   -0.536643  0.675051  0.878366
#
#    bacteria   viruses      lead  nitrates  nitrites   mercury  perchlorate  \
# 0 -0.363345 -0.869387 -0.781070  1.129767 -0.348629  0.609178     1.203362
# 1  1.002460  0.849782  0.009785 -1.409197  1.046960 -0.739005     0.892977
# 2 -0.818614 -0.861452 -0.368450  0.783298 -0.383518  0.272132     1.911763
# 3  1.184567  1.008475 -1.434385 -1.517469 -0.069511 -0.401960    -0.415275
# 4 -0.575804 -0.866742  0.302058 -0.555658 -0.383518 -0.739005     0.024578
# 5  1.063162  0.902680  0.611523 -0.012496  0.977180  0.272132     0.605207
#
#      radium    silver  is_safe
# 0  1.661842  1.338736      1.0
# 1  0.124811  0.851134      1.0
# 2  1.786699  2.035310      0.0
# 3 -0.516695  2.104968      1.0
# 4 -0.219622 -0.611672      1.0
# 5  1.076306  0.293875      1.0

# %%
x = data.drop('is_safe', axis = 1)
y = data['is_safe']

from collections import Counter
from imblearn.over_sampling import SMOTE

counter = Counter(y)
print(counter)


oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 25)

y_train = np.expand_dims(y_train, axis = -1)
x_train = np.expand_dims(x_train, axis = -1)
x_test = np.expand_dims(x_test, axis = -1)
y_tset = np.expand_dims(x_test, axis = -1)

counter = Counter(y)
print(counter)
print(y_train.shape)
print(x_train.shape)
# Out:
# Counter({0.0: 7084, 1.0: 909})
# Counter({1.0: 7084, 0.0: 7084})
# (11334, 1)
# (11334, 16, 1)

# %%
model = Sequential()
model.add(Conv1D(128, 3, padding="same",input_shape =(16,1), activation='relu'))
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
# model.add(Conv1D(64, 3, padding="same", activation='relu'))
# model.add(MaxPool1D(pool_size=(2)))  
# model.add(Dropout(0.5))
# model.add(LSTM(128, input_shape=(16,1), activation='relu', return_sequences=True))
# model.add(Dropout(0.2))
model.add(LSTM(128, activation='relu'))
model.add(Dropout(0.2))
# model.add(Dense(1024, activation='relu', input_shape=(16,1)))
# model.add(Dropout(0.3))
# model.add(BatchNormalization())
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# model.add(BatchNormalization())
# model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1,activation='sigmoid'))

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(x_train, y_train,
          batch_size=100,
          epochs=150,
          validation_split=0.2,callbacks=[early])
# Out:
# Epoch 1/150
# 91/91 [==============================] - 5s 35ms/step - loss: 0.5974 - accuracy: 0.6746 - val_loss: 0.6485 - val_accuracy: 0.7600
# Epoch 2/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.4122 - accuracy: 0.8169 - val_loss: 0.5567 - val_accuracy: 0.8306
# Epoch 3/150
# 91/91 [==============================] - 3s 28ms/step - loss: 0.3485 - accuracy: 0.8458 - val_loss: 0.4302 - val_accuracy: 0.8690
# Epoch 4/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.2969 - accuracy: 0.8722 - val_loss: 0.3603 - val_accuracy: 0.8571
# Epoch 5/150
# 91/91 [==============================] - 3s 32ms/step - loss: 0.2665 - accuracy: 0.8889 - val_loss: 0.2593 - val_accuracy: 0.8827
# Epoch 6/150
# 91/91 [==============================] - 3s 28ms/step - loss: 0.2521 - accuracy: 0.8919 - val_loss: 0.2407 - val_accuracy: 0.8990
# Epoch 7/150
# 91/91 [==============================] - 3s 28ms/step - loss: 0.2436 - accuracy: 0.8978 - val_loss: 0.2135 - val_accuracy: 0.9060
# Epoch 8/150
# 91/91 [==============================] - 3s 34ms/step - loss: 0.2237 - accuracy: 0.9070 - val_loss: 0.2067 - val_accuracy: 0.9162
# Epoch 9/150
# 91/91 [==============================] - 3s 31ms/step - loss: 0.2264 - accuracy: 0.9079 - val_loss: 0.2074 - val_accuracy: 0.9113
# Epoch 10/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.2155 - accuracy: 0.9111 - val_loss: 0.1963 - val_accuracy: 0.9171
# Epoch 11/150
# 91/91 [==============================] - 4s 40ms/step - loss: 0.2075 - accuracy: 0.9161 - val_loss: 0.1813 - val_accuracy: 0.9307
# Epoch 12/150
# 91/91 [==============================] - 2s 26ms/step - loss: 0.1982 - accuracy: 0.9193 - val_loss: 0.2025 - val_accuracy: 0.9206
# Epoch 13/150
# 91/91 [==============================] - 3s 31ms/step - loss: 0.1951 - accuracy: 0.9229 - val_loss: 0.1850 - val_accuracy: 0.9338
# Epoch 14/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1976 - accuracy: 0.9215 - val_loss: 0.1871 - val_accuracy: 0.9307
# Epoch 15/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1879 - accuracy: 0.9278 - val_loss: 0.1672 - val_accuracy: 0.9356
# Epoch 16/150
# 91/91 [==============================] - 4s 42ms/step - loss: 0.1782 - accuracy: 0.9279 - val_loss: 0.1687 - val_accuracy: 0.9400
# Epoch 17/150
# 91/91 [==============================] - 3s 31ms/step - loss: 0.1787 - accuracy: 0.9294 - val_loss: 0.1718 - val_accuracy: 0.9356
# Epoch 18/150
# 91/91 [==============================] - 3s 28ms/step - loss: 0.1708 - accuracy: 0.9348 - val_loss: 0.1697 - val_accuracy: 0.9378
# Epoch 19/150
# 91/91 [==============================] - 3s 35ms/step - loss: 0.1628 - accuracy: 0.9363 - val_loss: 0.1479 - val_accuracy: 0.9427
# Epoch 20/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1590 - accuracy: 0.9349 - val_loss: 0.1680 - val_accuracy: 0.9404
# Epoch 21/150
# 91/91 [==============================] - 3s 32ms/step - loss: 0.1678 - accuracy: 0.9318 - val_loss: 0.1656 - val_accuracy: 0.9382
# Epoch 22/150
# 91/91 [==============================] - 3s 27ms/step - loss: 0.1560 - accuracy: 0.9399 - val_loss: 0.1398 - val_accuracy: 0.9484
# Epoch 23/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1493 - accuracy: 0.9431 - val_loss: 0.1442 - val_accuracy: 0.9519
# Epoch 24/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1488 - accuracy: 0.9428 - val_loss: 0.1394 - val_accuracy: 0.9506
# Epoch 25/150
# 91/91 [==============================] - 3s 32ms/step - loss: 0.1462 - accuracy: 0.9431 - val_loss: 0.1854 - val_accuracy: 0.9312
# Epoch 26/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1392 - accuracy: 0.9453 - val_loss: 0.1623 - val_accuracy: 0.9466
# Epoch 27/150
# 91/91 [==============================] - 3s 27ms/step - loss: 0.1373 - accuracy: 0.9463 - val_loss: 0.1352 - val_accuracy: 0.9502
# Epoch 28/150
# 91/91 [==============================] - 2s 27ms/step - loss: 0.1330 - accuracy: 0.9471 - val_loss: 0.1703 - val_accuracy: 0.9330
# Epoch 00028: early stopping

# %%
evaluation = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 89/89 [==============================] - 1s 4ms/step - loss: 0.2006 - accuracy: 0.9164

# %%
pd.DataFrame(history.history)
pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
