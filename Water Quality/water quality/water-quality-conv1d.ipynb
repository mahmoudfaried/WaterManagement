# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import LSTM
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional     
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
df = pd.read_csv('../input/water-potability/water_potability.csv')
df.shape
# Out:
# (3276, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# None

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
X = df.drop(["Potability"], axis=1)
y = df["Potability"]
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=25)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
X_train.shape
# Out:
# (3196, 9, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
X_test.shape
# Out:
# (800, 9, 1)

# %%
model = Sequential()
model.add(Conv1D(128, 3, padding="same",input_shape =(9,1), activation='relu'))
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
model.add(Conv1D(64, 3, padding="same",input_shape =(9,1), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(Conv1D(64, 3, padding="same", activation='relu'))
model.add(MaxPool1D(pool_size=(2)))  
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(units=64))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train,
                    y_train,
                    epochs=200,
                    batch_size=100,
                    callbacks=[early],
                    validation_split=0.2,
                    verbose=1
                   )
# Out:
# Epoch 1/200
# 26/26 [==============================] - 1s 14ms/step - loss: 0.7266 - accuracy: 0.5348 - val_loss: 0.6894 - val_accuracy: 0.5750
# Epoch 2/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6883 - accuracy: 0.5669 - val_loss: 0.6868 - val_accuracy: 0.5703
# Epoch 3/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6710 - accuracy: 0.5810 - val_loss: 0.6851 - val_accuracy: 0.5641
# Epoch 4/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6577 - accuracy: 0.5998 - val_loss: 0.6840 - val_accuracy: 0.5688
# Epoch 5/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.6483 - accuracy: 0.6146 - val_loss: 0.6834 - val_accuracy: 0.5625
# Epoch 6/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6453 - accuracy: 0.6260 - val_loss: 0.6785 - val_accuracy: 0.5688
# Epoch 7/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6383 - accuracy: 0.6166 - val_loss: 0.6733 - val_accuracy: 0.5938
# Epoch 8/200
# 26/26 [==============================] - 0s 11ms/step - loss: 0.6404 - accuracy: 0.6307 - val_loss: 0.6672 - val_accuracy: 0.6141
# Epoch 9/200
# 26/26 [==============================] - 0s 9ms/step - loss: 0.6259 - accuracy: 0.6338 - val_loss: 0.6684 - val_accuracy: 0.5891
# Epoch 10/200
# 26/26 [==============================] - 0s 9ms/step - loss: 0.6244 - accuracy: 0.6526 - val_loss: 0.6634 - val_accuracy: 0.5969
# Epoch 11/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6142 - accuracy: 0.6561 - val_loss: 0.6520 - val_accuracy: 0.6219
# Epoch 12/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6079 - accuracy: 0.6553 - val_loss: 0.6380 - val_accuracy: 0.6484
# Epoch 13/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6141 - accuracy: 0.6526 - val_loss: 0.6372 - val_accuracy: 0.6391
# Epoch 14/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6070 - accuracy: 0.6631 - val_loss: 0.6252 - val_accuracy: 0.6500
# Epoch 15/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.6022 - accuracy: 0.6643 - val_loss: 0.6196 - val_accuracy: 0.6594
# Epoch 16/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5880 - accuracy: 0.6815 - val_loss: 0.6296 - val_accuracy: 0.6203
# Epoch 17/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5995 - accuracy: 0.6733 - val_loss: 0.6185 - val_accuracy: 0.6406
# Epoch 18/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5877 - accuracy: 0.6815 - val_loss: 0.6025 - val_accuracy: 0.6797
# Epoch 19/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5849 - accuracy: 0.6804 - val_loss: 0.5987 - val_accuracy: 0.6797
# Epoch 20/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5969 - accuracy: 0.6682 - val_loss: 0.6004 - val_accuracy: 0.6766
# Epoch 21/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5732 - accuracy: 0.6987 - val_loss: 0.5976 - val_accuracy: 0.6625
# Epoch 22/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5741 - accuracy: 0.6909 - val_loss: 0.5980 - val_accuracy: 0.6625
# Epoch 23/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5731 - accuracy: 0.6894 - val_loss: 0.5979 - val_accuracy: 0.6672
# Epoch 24/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5687 - accuracy: 0.6913 - val_loss: 0.5991 - val_accuracy: 0.6578
# Epoch 25/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5658 - accuracy: 0.7031 - val_loss: 0.5905 - val_accuracy: 0.6656
# Epoch 26/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5632 - accuracy: 0.6890 - val_loss: 0.5861 - val_accuracy: 0.6859
# Epoch 27/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5666 - accuracy: 0.6991 - val_loss: 0.5859 - val_accuracy: 0.6969
# Epoch 28/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5575 - accuracy: 0.7117 - val_loss: 0.5880 - val_accuracy: 0.6750
# Epoch 29/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5393 - accuracy: 0.7164 - val_loss: 0.6173 - val_accuracy: 0.6391
# Epoch 30/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5504 - accuracy: 0.7136 - val_loss: 0.6148 - val_accuracy: 0.6484
# Epoch 31/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5463 - accuracy: 0.7031 - val_loss: 0.5908 - val_accuracy: 0.6859
# Epoch 32/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5389 - accuracy: 0.7183 - val_loss: 0.5816 - val_accuracy: 0.6859
# Epoch 33/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5449 - accuracy: 0.7085 - val_loss: 0.5876 - val_accuracy: 0.6984
# Epoch 34/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5347 - accuracy: 0.7175 - val_loss: 0.5931 - val_accuracy: 0.6891
# Epoch 35/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5288 - accuracy: 0.7230 - val_loss: 0.6038 - val_accuracy: 0.6656
# Epoch 36/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5287 - accuracy: 0.7332 - val_loss: 0.5744 - val_accuracy: 0.6797
# Epoch 37/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5213 - accuracy: 0.7355 - val_loss: 0.5906 - val_accuracy: 0.6766
# Epoch 38/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5256 - accuracy: 0.7340 - val_loss: 0.5977 - val_accuracy: 0.6875
# Epoch 39/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5023 - accuracy: 0.7453 - val_loss: 0.5730 - val_accuracy: 0.6922
# Epoch 40/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5109 - accuracy: 0.7433 - val_loss: 0.5788 - val_accuracy: 0.6922
# Epoch 41/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5189 - accuracy: 0.7379 - val_loss: 0.5784 - val_accuracy: 0.6891
# Epoch 42/200
# 26/26 [==============================] - 0s 7ms/step - loss: 0.5179 - accuracy: 0.7445 - val_loss: 0.5857 - val_accuracy: 0.6953
# Epoch 43/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.5062 - accuracy: 0.7414 - val_loss: 0.5816 - val_accuracy: 0.6891
# Epoch 44/200
# 26/26 [==============================] - 0s 6ms/step - loss: 0.4902 - accuracy: 0.7578 - val_loss: 0.6009 - val_accuracy: 0.6812
# Epoch 00044: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
pd.DataFrame(history.history)
pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
y_pred = model.predict(X_test)
y_pred = [ 1 if y>=0.5 else 0 for y in y_pred ]

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67       397
#            1       0.68      0.60      0.64       403
#
#     accuracy                           0.65       800
#    macro avg       0.66      0.65      0.65       800
# weighted avg       0.66      0.65      0.65       800

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[280 117]
#  [160 243]]
# Accuracy: 65.375%

# %%
from keras.models import load_model

model.save('model.h5')  # creates a HDF5 file 'my_model.h5'
del model  # deletes the existing model

# returns a compiled model
# identical to the previous one
model = load_model('model.h5')
