# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import LSTM
#from keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional     
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
df = pd.read_csv('../input/water-potability/water_potability.csv')
df.shape
# Out:
# (3276, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB
# None

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.080795  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246  333.775777    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.775777    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
X = df.drop(["Potability"], axis=1)
y = df["Potability"]
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=25)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
X_train.shape
# Out:
# (3196, 9, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
X_test.shape
# Out:
# (800, 9, 1)

# %%
model = Sequential()
model.add(GRU(units=128, return_sequences=True, dropout=0.3,
recurrent_dropout=0.4, input_shape=(9,1)))

model.add(GRU(units=64, return_sequences=True,activation='relu',
dropout=0.25, recurrent_dropout=0.3))

model.add(BatchNormalization())

model.add(GRU(units=64,activation='relu',dropout=0.3, recurrent_dropout=0.35))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['accuracy'])
history = model.fit(X_train,
                    y_train,
                    epochs=200,
                    batch_size =100,
                    callbacks=[early],
                    validation_data=(X_test, y_test), verbose=1
          )
# Out:
# 2022-11-02 15:38:41.180936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.181938: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.485366: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.486374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.487282: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.488151: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.489945: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-02 15:38:41.755649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.756559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.757336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.758154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.759012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:41.759914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.706777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.708194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.709425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.710690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.711915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.713043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-11-02 15:38:46.719205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-02 15:38:46.720366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2022-11-02 15:38:47.616963: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 32/32 [==============================] - 12s 130ms/step - loss: 0.7008 - accuracy: 0.5122 - val_loss: 0.6932 - val_accuracy: 0.4963
# Epoch 2/200
# 32/32 [==============================] - 4s 125ms/step - loss: 0.6949 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.4963
# Epoch 3/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.6967 - accuracy: 0.5094 - val_loss: 0.6931 - val_accuracy: 0.4963
# Epoch 4/200
# 32/32 [==============================] - 4s 132ms/step - loss: 0.6930 - accuracy: 0.5185 - val_loss: 0.6932 - val_accuracy: 0.4950
# Epoch 5/200
# 32/32 [==============================] - 4s 122ms/step - loss: 0.6956 - accuracy: 0.4987 - val_loss: 0.6933 - val_accuracy: 0.4950
# Epoch 6/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.6909 - accuracy: 0.5238 - val_loss: 0.6933 - val_accuracy: 0.5013
# Epoch 7/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.6900 - accuracy: 0.5175 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 8/200
# 32/32 [==============================] - 4s 122ms/step - loss: 0.6941 - accuracy: 0.5066 - val_loss: 0.6927 - val_accuracy: 0.5138
# Epoch 9/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.6925 - accuracy: 0.5257 - val_loss: 0.6928 - val_accuracy: 0.5063
# Epoch 10/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.6939 - accuracy: 0.4972 - val_loss: 0.6929 - val_accuracy: 0.5038
# Epoch 11/200
# 32/32 [==============================] - 4s 121ms/step - loss: 0.6918 - accuracy: 0.5203 - val_loss: 0.6923 - val_accuracy: 0.5163
# Epoch 12/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.6920 - accuracy: 0.5203 - val_loss: 0.6929 - val_accuracy: 0.5312
# Epoch 13/200
# 32/32 [==============================] - 4s 131ms/step - loss: 0.6913 - accuracy: 0.5291 - val_loss: 0.6918 - val_accuracy: 0.5263
# Epoch 14/200
# 32/32 [==============================] - 4s 125ms/step - loss: 0.6930 - accuracy: 0.5072 - val_loss: 0.6929 - val_accuracy: 0.5263
# Epoch 15/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.6892 - accuracy: 0.5257 - val_loss: 0.6919 - val_accuracy: 0.5325
# Epoch 16/200
# 32/32 [==============================] - 3s 107ms/step - loss: 0.6932 - accuracy: 0.5031 - val_loss: 0.6915 - val_accuracy: 0.5312
# Epoch 17/200
# 32/32 [==============================] - 4s 122ms/step - loss: 0.6914 - accuracy: 0.5135 - val_loss: 0.6944 - val_accuracy: 0.5038
# Epoch 18/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.6927 - accuracy: 0.5091 - val_loss: 0.6901 - val_accuracy: 0.5462
# Epoch 19/200
# 32/32 [==============================] - 3s 109ms/step - loss: 0.6891 - accuracy: 0.5272 - val_loss: 0.6891 - val_accuracy: 0.5425
# Epoch 20/200
# 32/32 [==============================] - 4s 121ms/step - loss: 0.6894 - accuracy: 0.5366 - val_loss: 0.6902 - val_accuracy: 0.5188
# Epoch 21/200
# 32/32 [==============================] - 4s 133ms/step - loss: 0.6905 - accuracy: 0.5282 - val_loss: 0.6934 - val_accuracy: 0.5150
# Epoch 22/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.6913 - accuracy: 0.5235 - val_loss: 0.6903 - val_accuracy: 0.5312
# Epoch 23/200
# 32/32 [==============================] - 4s 120ms/step - loss: 0.6882 - accuracy: 0.5347 - val_loss: 0.6872 - val_accuracy: 0.5675
# Epoch 24/200
# 32/32 [==============================] - 4s 110ms/step - loss: 0.6866 - accuracy: 0.5435 - val_loss: 0.6873 - val_accuracy: 0.5362
# Epoch 25/200
# 32/32 [==============================] - 3s 105ms/step - loss: 0.6918 - accuracy: 0.5219 - val_loss: 0.6873 - val_accuracy: 0.5300
# Epoch 26/200
# 32/32 [==============================] - 4s 117ms/step - loss: 0.6885 - accuracy: 0.5344 - val_loss: 0.6854 - val_accuracy: 0.5713
# Epoch 27/200
# 32/32 [==============================] - 3s 108ms/step - loss: 0.6885 - accuracy: 0.5253 - val_loss: 0.6814 - val_accuracy: 0.5475
# Epoch 28/200
# 32/32 [==============================] - 3s 106ms/step - loss: 0.6840 - accuracy: 0.5488 - val_loss: 0.6818 - val_accuracy: 0.5600
# Epoch 29/200
# 32/32 [==============================] - 4s 125ms/step - loss: 0.6873 - accuracy: 0.5457 - val_loss: 0.6837 - val_accuracy: 0.5450
# Epoch 30/200
# 32/32 [==============================] - 4s 128ms/step - loss: 0.6846 - accuracy: 0.5529 - val_loss: 0.6823 - val_accuracy: 0.5575
# Epoch 31/200
# 32/32 [==============================] - 3s 103ms/step - loss: 0.6846 - accuracy: 0.5513 - val_loss: 0.6830 - val_accuracy: 0.5525
# Epoch 32/200
# 32/32 [==============================] - 4s 118ms/step - loss: 0.6855 - accuracy: 0.5485 - val_loss: 0.6830 - val_accuracy: 0.5487
# Epoch 00032: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
pd.DataFrame(history.history)
pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
# Out:
# Text(0, 0.5, 'accuracy')

# %%
y_pred = model.predict(X_test)
y_pred = [ 1 if y>=0.5 else 0 for y in y_pred ]

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.81      0.64       397
#            1       0.61      0.29      0.40       403
#
#     accuracy                           0.55       800
#    macro avg       0.57      0.55      0.52       800
# weighted avg       0.57      0.55      0.52       800

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)

accuracy = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+cm[1][1])
print("Accuracy: "+ str(accuracy*100)+"%")
# Out:
# [[321  76]
#  [285 118]]
# Accuracy: 54.87499999999999%
