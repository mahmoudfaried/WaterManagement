# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout # importing dense layer
from sklearn import preprocessing
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer
from sklearn import preprocessing
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer
from sklearn.model_selection import GridSearchCV

# %%
dataset = pd.read_csv('../input/rainfall-prediction/dataset1.csv')

# %%
dataset
# Out:
#      day  pressure   maxtemp  temparature  mintemp  dewpoint  humidity   \
# 0      1     1025.9     19.9         18.3     16.8      13.1         72
# 1      2     1022.0     21.7         18.9     17.2      15.6         81
# 2      3     1019.7     20.3         19.3     18.0      18.4         95
# 3      4     1018.9     22.3         20.6     19.1      18.8         90
# 4      5     1015.9     21.3         20.7     20.2      19.9         95
# ..   ...        ...      ...          ...      ...       ...        ...
# 361   27     1022.7     18.8         17.7     16.9      15.0         84
# 362   28     1026.6     18.6         17.3     16.3      12.8         75
# 363   29     1025.9     18.9         17.7     16.4      13.3         75
# 364   30     1025.3     19.2         17.3     15.2      13.3         78
# 365   31     1026.4     20.5         17.8     15.5      13.0         74
#
#      cloud  rainfall  sunshine           winddirection  windspeed
# 0        49      yes       9.3                    80.0       26.3
# 1        83      yes       0.6                    50.0       15.3
# 2        91      yes       0.0                    40.0       14.2
# 3        88      yes       1.0                    50.0       16.9
# 4        81      yes       0.0                    40.0       13.7
# ..      ...      ...       ...                     ...        ...
# 361      90      yes       0.0                    30.0       18.4
# 362      85      yes       1.0                    20.0       25.9
# 363      78      yes       4.6                    70.0       33.4
# 364      86      yes       1.2                    20.0       20.9
# 365      66       no       5.7                    20.0       23.3
#
# [366 rows x 12 columns]

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   day                     366 non-null    int64
#  1   pressure                366 non-null    float64
#  2   maxtemp                 366 non-null    float64
#  3   temparature             366 non-null    float64
#  4   mintemp                 366 non-null    float64
#  5   dewpoint                366 non-null    float64
#  6   humidity                366 non-null    int64
#  7   cloud                   366 non-null    int64
#  8   rainfall                366 non-null    object
#  9   sunshine                366 non-null    float64
#  10           winddirection  365 non-null    float64
#  11  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 34.4+ KB

# %%
# remove attribute 'day'
dataset.drop(['day'],axis=1,inplace=True)
dataset.shape
# Out:
# (366, 11)

# %%
dataset['rainfall'].value_counts()
# Out:
# yes    249
# no     117
# Name: rainfall, dtype: int64

# %%
multi_label = pd.DataFrame(dataset.rainfall)
le = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le.fit_transform)
dataset['rainfall'] = enc_label
dataset
# Out:
#      pressure   maxtemp  temparature  mintemp  dewpoint  humidity   cloud   \
# 0       1025.9     19.9         18.3     16.8      13.1         72      49
# 1       1022.0     21.7         18.9     17.2      15.6         81      83
# 2       1019.7     20.3         19.3     18.0      18.4         95      91
# 3       1018.9     22.3         20.6     19.1      18.8         90      88
# 4       1015.9     21.3         20.7     20.2      19.9         95      81
# ..         ...      ...          ...      ...       ...        ...     ...
# 361     1022.7     18.8         17.7     16.9      15.0         84      90
# 362     1026.6     18.6         17.3     16.3      12.8         75      85
# 363     1025.9     18.9         17.7     16.4      13.3         75      78
# 364     1025.3     19.2         17.3     15.2      13.3         78      86
# 365     1026.4     20.5         17.8     15.5      13.0         74      66
#
#      rainfall  sunshine           winddirection  windspeed
# 0           1       9.3                    80.0       26.3
# 1           1       0.6                    50.0       15.3
# 2           1       0.0                    40.0       14.2
# 3           1       1.0                    50.0       16.9
# 4           1       0.0                    40.0       13.7
# ..        ...       ...                     ...        ...
# 361         1       0.0                    30.0       18.4
# 362         1       1.0                    20.0       25.9
# 363         1       4.6                    70.0       33.4
# 364         1       1.2                    20.0       20.9
# 365         0       5.7                    20.0       23.3
#
# [366 rows x 11 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  365 non-null    float64
#  10  windspeed               365 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
dataset['windspeed'] = dataset['windspeed'].fillna(0)

# %%
dataset['         winddirection'] = dataset['         winddirection'].fillna(0)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  366 non-null    float64
#  10  windspeed               366 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
y_train= dataset[['rainfall']]
X_train= dataset.drop(labels=['rainfall'], axis=1)

print('X_train has shape:',X_train.shape,'\ny_train has shape:',y_train.shape)
# Out:
# X_train has shape: (366, 10)
# y_train has shape: (366, 1)

# %%
y=y_train
x=X_train

# %%
dataset['rainfall'].value_counts()
# Out:
# 1    249
# 0    117
# Name: rainfall, dtype: int64

# %%
# Oversample and plot imbalanced dataset with SMOTE
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from matplotlib import pyplot
from numpy import where

# %%
y=np.array(y, dtype=np.int64)
x=np.array(x, dtype=np.int64)
x
# Out:
# array([[1025,   19,   18, ...,    9,   80,   26],
#        [1022,   21,   18, ...,    0,   50,   15],
#        [1019,   20,   19, ...,    0,   40,   14],
#        ...,
#        [1025,   18,   17, ...,    4,   70,   33],
#        [1025,   19,   17, ...,    1,   20,   20],
#        [1026,   20,   17, ...,    5,   20,   23]])

# %%
oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

# %%
counter = Counter(y)
print(counter)
# Out:
# Counter({1: 249, 0: 249})

# %%
for label, _ in counter.items():
    row_ix = where(y == label)[0]
    pyplot.scatter(x[row_ix, 0], x[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %%
X_train=np.array(x)
y_train=np.array(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (398, 10, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test.shape
# Out:
# (100, 10, 1)

# %%
 dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   pressure                366 non-null    float64
#  1   maxtemp                 366 non-null    float64
#  2   temparature             366 non-null    float64
#  3   mintemp                 366 non-null    float64
#  4   dewpoint                366 non-null    float64
#  5   humidity                366 non-null    int64
#  6   cloud                   366 non-null    int64
#  7   rainfall                366 non-null    int64
#  8   sunshine                366 non-null    float64
#  9            winddirection  366 non-null    float64
#  10  windspeed               366 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 31.6 KB

# %%
#def create_model():    
  #  model = Sequential()  
   # model.add(Conv1D(128, 3, padding="same",input_shape = (X_train.shape[1], 1), activation='relu'))
   # model.add(MaxPool1D(pool_size=(2))) 
   # model.add(BatchNormalization())
    #model.add(Dropout(0.2))
    #model.add(Conv1D(128, 3, padding="same", activation='relu'))
    #model.add(MaxPool1D(pool_size=(2))) 
    #model.add(BatchNormalization())
    #model.add(Dropout(0.2))
    #model.add(Flatten())
    #model.add(Dense(units=64))
    #model.add(Dense(units= 1,activation='sigmoid' ))
    #model.compile(loss='binary_crossentropy',optimizer = 'adam', metrics=['accuracy'])
    #return model

# %%
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
#model= model.compile(loss="binary_crossentropy", metrics=['accuracy'])
#model = KerasClassifier(create_model, verbose=0, )

# %%
#batch_size = [5,10, 20, 30]
#epochs = [100,120,150,200]
#optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']
#param_grid = dict(batch_size=batch_size,epochs=epochs)
#grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
#grid_result = grid.fit(X_train, y_train)
# summarize results
#print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#means = grid_result.cv_results_['mean_test_score']
#stds = grid_result.cv_results_['std_test_score']
#params = grid_result.cv_results_['params']
#for mean, stdev, param in zip(means, stds, params):
 #   print("%f (%f) with: %r" % (mean, stdev, param))

# %%
    model = Sequential()  
    model.add(Conv1D(128, 3, padding="same",input_shape = (X_train.shape[1], 1), activation='relu'))
    model.add(MaxPool1D(pool_size=(2))) 

    model.add(Dropout(0.2))
    model.add(Conv1D(64, 3, padding="same", activation='relu'))
    model.add(MaxPool1D(pool_size=(2))) 
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(units=64))
# output layer with softmax activation
  

    
    model.add(Dense(units= 1,activation='sigmoid' ))

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 10, 128)           512
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 128)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 5, 64)             24640
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 2, 64)             0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 64)             256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 64)             0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 33,729
# Trainable params: 33,601
# Non-trainable params: 128
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
history = model.fit(X_train, y_train, epochs=100, batch_size=5,validation_split=0.2,callbacks=[early],)
# Out:
# Epoch 1/100
# 64/64 [==============================] - 1s 6ms/step - loss: 0.5733 - accuracy: 0.6918 - val_loss: 0.6271 - val_accuracy: 0.6000
# Epoch 2/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5326 - accuracy: 0.7358 - val_loss: 0.5704 - val_accuracy: 0.7750
# Epoch 3/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.5010 - accuracy: 0.7516 - val_loss: 0.5102 - val_accuracy: 0.7875
# Epoch 4/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4906 - accuracy: 0.7610 - val_loss: 0.5258 - val_accuracy: 0.7750
# Epoch 5/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4719 - accuracy: 0.7642 - val_loss: 0.4602 - val_accuracy: 0.8000
# Epoch 6/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4773 - accuracy: 0.7830 - val_loss: 0.4389 - val_accuracy: 0.7500
# Epoch 7/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.8176 - val_loss: 0.4196 - val_accuracy: 0.7750
# Epoch 8/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.7799 - val_loss: 0.4303 - val_accuracy: 0.8000
# Epoch 9/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4720 - accuracy: 0.7673 - val_loss: 0.4632 - val_accuracy: 0.8000
# Epoch 10/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4338 - accuracy: 0.7893 - val_loss: 0.4241 - val_accuracy: 0.8250
# Epoch 11/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4138 - accuracy: 0.8270 - val_loss: 0.4512 - val_accuracy: 0.8000
# Epoch 12/100
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4176 - accuracy: 0.7956 - val_loss: 0.4537 - val_accuracy: 0.7875
# Epoch 13/100
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4296 - accuracy: 0.8019 - val_loss: 0.5095 - val_accuracy: 0.7500
# Epoch 14/100
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4393 - accuracy: 0.8019 - val_loss: 0.4711 - val_accuracy: 0.8000
# Epoch 15/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4072 - accuracy: 0.8019 - val_loss: 0.4214 - val_accuracy: 0.7750
# Epoch 16/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.8082 - val_loss: 0.4107 - val_accuracy: 0.8375
# Epoch 17/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4076 - accuracy: 0.8270 - val_loss: 0.4862 - val_accuracy: 0.7500
# Epoch 18/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8050 - val_loss: 0.3884 - val_accuracy: 0.8500
# Epoch 19/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4174 - accuracy: 0.8208 - val_loss: 0.4227 - val_accuracy: 0.8000
# Epoch 20/100
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4464 - accuracy: 0.7925 - val_loss: 0.5173 - val_accuracy: 0.7125
# Epoch 21/100
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3995 - accuracy: 0.8333 - val_loss: 0.4830 - val_accuracy: 0.7875
# Epoch 22/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8239 - val_loss: 0.4129 - val_accuracy: 0.8250
# Epoch 23/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3613 - accuracy: 0.8302 - val_loss: 0.4454 - val_accuracy: 0.8250
# Epoch 24/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3712 - accuracy: 0.8270 - val_loss: 0.4678 - val_accuracy: 0.8125
# Epoch 25/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3983 - accuracy: 0.8113 - val_loss: 0.4379 - val_accuracy: 0.8250
# Epoch 26/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.8302 - val_loss: 0.4175 - val_accuracy: 0.8500
# Epoch 27/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3884 - accuracy: 0.8082 - val_loss: 0.3902 - val_accuracy: 0.8500
# Epoch 28/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3935 - accuracy: 0.8270 - val_loss: 0.4540 - val_accuracy: 0.8250
# Epoch 29/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3800 - accuracy: 0.8082 - val_loss: 0.4210 - val_accuracy: 0.8375
# Epoch 30/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3747 - accuracy: 0.8302 - val_loss: 0.4189 - val_accuracy: 0.8375
# Epoch 31/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3991 - accuracy: 0.8396 - val_loss: 0.4344 - val_accuracy: 0.7500
# Epoch 32/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3849 - accuracy: 0.8270 - val_loss: 0.3965 - val_accuracy: 0.8125
# Epoch 33/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3733 - accuracy: 0.8302 - val_loss: 0.4114 - val_accuracy: 0.8500
# Epoch 34/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.4060 - accuracy: 0.8208 - val_loss: 0.3934 - val_accuracy: 0.8375
# Epoch 35/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.8396 - val_loss: 0.4105 - val_accuracy: 0.8625
# Epoch 36/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3798 - accuracy: 0.8176 - val_loss: 0.4118 - val_accuracy: 0.8375
# Epoch 37/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3732 - accuracy: 0.8553 - val_loss: 0.4039 - val_accuracy: 0.8375
# Epoch 38/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3859 - accuracy: 0.8019 - val_loss: 0.3695 - val_accuracy: 0.8625
# Epoch 39/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3554 - accuracy: 0.8208 - val_loss: 0.4337 - val_accuracy: 0.8250
# Epoch 40/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3522 - accuracy: 0.8491 - val_loss: 0.4224 - val_accuracy: 0.8375
# Epoch 41/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3460 - accuracy: 0.8459 - val_loss: 0.3919 - val_accuracy: 0.8500
# Epoch 42/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3456 - accuracy: 0.8459 - val_loss: 0.4799 - val_accuracy: 0.8000
# Epoch 43/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3680 - accuracy: 0.8270 - val_loss: 0.4164 - val_accuracy: 0.8625
# Epoch 44/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3217 - accuracy: 0.8711 - val_loss: 0.4610 - val_accuracy: 0.8375
# Epoch 45/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3843 - accuracy: 0.8333 - val_loss: 0.5268 - val_accuracy: 0.7875
# Epoch 46/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3542 - accuracy: 0.8333 - val_loss: 0.3713 - val_accuracy: 0.8625
# Epoch 47/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3530 - accuracy: 0.8270 - val_loss: 0.4099 - val_accuracy: 0.8250
# Epoch 48/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3589 - accuracy: 0.8553 - val_loss: 0.3801 - val_accuracy: 0.8500
# Epoch 49/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3705 - accuracy: 0.8396 - val_loss: 0.4174 - val_accuracy: 0.8875
# Epoch 50/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3613 - accuracy: 0.8270 - val_loss: 0.3708 - val_accuracy: 0.8375
# Epoch 51/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3661 - accuracy: 0.8365 - val_loss: 0.3834 - val_accuracy: 0.8500
# Epoch 52/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.8616 - val_loss: 0.3749 - val_accuracy: 0.8375
# Epoch 53/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3779 - accuracy: 0.8302 - val_loss: 0.3691 - val_accuracy: 0.8625
# Epoch 54/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3298 - accuracy: 0.8679 - val_loss: 0.3980 - val_accuracy: 0.8500
# Epoch 55/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3441 - accuracy: 0.8459 - val_loss: 0.3851 - val_accuracy: 0.8375
# Epoch 56/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3002 - accuracy: 0.8679 - val_loss: 0.3576 - val_accuracy: 0.8625
# Epoch 57/100
# 64/64 [==============================] - 0s 7ms/step - loss: 0.3492 - accuracy: 0.8491 - val_loss: 0.3855 - val_accuracy: 0.8500
# Epoch 58/100
# 64/64 [==============================] - 0s 6ms/step - loss: 0.3228 - accuracy: 0.8491 - val_loss: 0.4079 - val_accuracy: 0.8875
# Epoch 59/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3244 - accuracy: 0.8553 - val_loss: 0.4896 - val_accuracy: 0.8250
# Epoch 60/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3325 - accuracy: 0.8459 - val_loss: 0.3990 - val_accuracy: 0.8625
# Epoch 61/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3251 - accuracy: 0.8585 - val_loss: 0.3981 - val_accuracy: 0.8875
# Epoch 62/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8553 - val_loss: 0.4822 - val_accuracy: 0.7875
# Epoch 63/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3131 - accuracy: 0.8679 - val_loss: 0.4112 - val_accuracy: 0.8625
# Epoch 64/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3301 - accuracy: 0.8836 - val_loss: 0.3868 - val_accuracy: 0.8500
# Epoch 65/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3209 - accuracy: 0.8522 - val_loss: 0.4265 - val_accuracy: 0.8500
# Epoch 66/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3100 - accuracy: 0.8553 - val_loss: 0.4363 - val_accuracy: 0.8500
# Epoch 67/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3462 - accuracy: 0.8491 - val_loss: 0.3726 - val_accuracy: 0.8875
# Epoch 68/100
# 64/64 [==============================] - 0s 4ms/step - loss: 0.3388 - accuracy: 0.8491 - val_loss: 0.3787 - val_accuracy: 0.8750
# Epoch 69/100
# 64/64 [==============================] - 0s 5ms/step - loss: 0.3232 - accuracy: 0.8679 - val_loss: 0.4018 - val_accuracy: 0.8250
# Epoch 00069: early stopping

# %%
score =model.evaluate(X_test, y_test, verbose=1)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4770 - accuracy: 0.7400
# Test loss: 0.4769613742828369
# Test accuracy: 0.7400000095367432

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")

pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
