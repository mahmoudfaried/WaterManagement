# %%
#Import some libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

import warnings

warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D,Dropout,Input,Activation,BatchNormalization,SimpleRNN
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from sklearn import preprocessing
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer
from sklearn.model_selection import GridSearchCV
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from matplotlib import pyplot
from numpy import where
from imblearn.over_sampling import SMOTE

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from keras.models import Model
from keras.models import Sequential
from keras.preprocessing import sequence
from keras.layers import Dense,GRU, Conv1D, Flatten,LSTM, MaxPooling1D,Dropout,Input,Activation,BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from numpy import unique
from keras.layers import Dense, Conv2D, MaxPool1D, Flatten, Dropout # importing dense layer
from sklearn import preprocessing
from keras.layers.embeddings import Embedding
from sklearn.preprocessing import (StandardScaler, OrdinalEncoder,LabelEncoder, MinMaxScaler, OneHotEncoder)
from sklearn.preprocessing import Normalizer, MaxAbsScaler , RobustScaler, PowerTransformer

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/weather-dataset-rattle-package/weatherAUS.csv

# %%
#Loading data set
df = pd.read_csv("../input/weather-dataset-rattle-package/weatherAUS.csv")

# %%
#dimensions of dataset
#There are 145460 rows and 23 columns
df.shape
# Out:
# (145460, 23)

# %%
#Preview dataset
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
#remove date predictor in dataset
df.drop("Date", axis = 1, inplace = True)

# %%
#preview dataset while dropping date
df.shape
# Out:
# (145460, 22)

# %%
#Checking the columns in dataset
df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.RainToday.value_counts()
# Out:
# No     110319
# Yes     31880
# Name: RainToday, dtype: int64

# %%
df.RainTomorrow.value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
# Info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        143975 non-null  float64
#  2   MaxTemp        144199 non-null  float64
#  3   Rainfall       142199 non-null  float64
#  4   Evaporation    82670 non-null   float64
#  5   Sunshine       75625 non-null   float64
#  6   WindGustDir    135134 non-null  object
#  7   WindGustSpeed  135197 non-null  float64
#  8   WindDir9am     134894 non-null  object
#  9   WindDir3pm     141232 non-null  object
#  10  WindSpeed9am   143693 non-null  float64
#  11  WindSpeed3pm   142398 non-null  float64
#  12  Humidity9am    142806 non-null  float64
#  13  Humidity3pm    140953 non-null  float64
#  14  Pressure9am    130395 non-null  float64
#  15  Pressure3pm    130432 non-null  float64
#  16  Cloud9am       89572 non-null   float64
#  17  Cloud3pm       86102 non-null   float64
#  18  Temp9am        143693 non-null  float64
#  19  Temp3pm        141851 non-null  float64
#  20  RainToday      142199 non-null  object
#  21  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(6)
# memory usage: 24.4+ MB

# %%
#Checking null value count in data
df.isnull().sum()
# Out:
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#Dropping the null values in dependent variable
#Use df1 veriable for train data
df1 = df[df['RainTomorrow'].notna()]   #This is our training data
df1
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Albury     13.4     22.9       0.6          NaN       NaN
# 1        Albury      7.4     25.1       0.0          NaN       NaN
# 2        Albury     12.9     25.7       0.0          NaN       NaN
# 3        Albury      9.2     28.0       0.0          NaN       NaN
# 4        Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 145454    Uluru      3.5     21.8       0.0          NaN       NaN
# 145455    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458    Uluru      7.8     27.0       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0                W           44.0          W        WNW  ...         71.0
# 1              WNW           44.0        NNW        WSW  ...         44.0
# 2              WSW           46.0          W        WSW  ...         38.0
# 3               NE           24.0         SE          E  ...         45.0
# 4                W           41.0        ENE         NW  ...         82.0
# ...            ...            ...        ...        ...  ...          ...
# 145454           E           31.0        ESE          E  ...         59.0
# 145455           E           31.0         SE        ENE  ...         51.0
# 145456         NNW           22.0         SE          N  ...         56.0
# 145457           N           37.0         SE        WNW  ...         53.0
# 145458          SE           28.0        SSE          N  ...         51.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145454         27.0       1024.7       1021.2       NaN       NaN      9.4
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145454     20.9         No            No
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
#
# [142193 rows x 22 columns]

# %%
#Dimension of dataset while dropping null values
df1.shape
# Out:
# (142193, 22)

# %%
#info of dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 145458
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       142193 non-null  object
#  1   MinTemp        141556 non-null  float64
#  2   MaxTemp        141871 non-null  float64
#  3   Rainfall       140787 non-null  float64
#  4   Evaporation    81350 non-null   float64
#  5   Sunshine       74377 non-null   float64
#  6   WindGustDir    132863 non-null  object
#  7   WindGustSpeed  132923 non-null  float64
#  8   WindDir9am     132180 non-null  object
#  9   WindDir3pm     138415 non-null  object
#  10  WindSpeed9am   140845 non-null  float64
#  11  WindSpeed3pm   139563 non-null  float64
#  12  Humidity9am    140419 non-null  float64
#  13  Humidity3pm    138583 non-null  float64
#  14  Pressure9am    128179 non-null  float64
#  15  Pressure3pm    128212 non-null  float64
#  16  Cloud9am       88536 non-null   float64
#  17  Cloud3pm       85099 non-null   float64
#  18  Temp9am        141289 non-null  float64
#  19  Temp3pm        139467 non-null  float64
#  20  RainToday      140787 non-null  object
#  21  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(6)
# memory usage: 25.0+ MB

# %%
# find categorical variables

categorical = [var for var in df1.columns if df1[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :', categorical)
# Out:
# There are 6 categorical variables
#
# The categorical variables are : ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
#Display categorical variables
df1[categorical].head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0   Albury           W          W        WNW        No           No
# 1   Albury         WNW        NNW        WSW        No           No
# 2   Albury         WSW          W        WSW        No           No
# 3   Albury          NE         SE          E        No           No
# 4   Albury           W        ENE         NW        No           No

# %%
# find numerical variables

numerical = [var for var in df1.columns if df1[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :', numerical)
# Out:
# There are 16 numerical variables
#
# The numerical variables are : ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
#Display nemerical variables
df1[numerical].head()     #Missing values in numerical variables
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          NaN       NaN           44.0
# 1      7.4     25.1       0.0          NaN       NaN           44.0
# 2     12.9     25.7       0.0          NaN       NaN           46.0
# 3      9.2     28.0       0.0          NaN       NaN           24.0
# 4     17.5     32.3       1.0          NaN       NaN           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0          20.0          24.0         71.0         22.0       1007.7
# 1           4.0          22.0         44.0         25.0       1010.6
# 2          19.0          26.0         38.0         30.0       1007.6
# 3          11.0           9.0         45.0         16.0       1017.6
# 4           7.0          20.0         82.0         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 0       1007.1       8.0       NaN     16.9     21.8
# 1       1007.8       NaN       NaN     17.2     24.3
# 2       1008.7       NaN       2.0     21.0     23.2
# 3       1012.8       NaN       NaN     18.1     26.5
# 4       1006.0       7.0       8.0     17.8     29.7

# %%
#checking null values in dataframe
df1.isna().sum()
# Out:
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RainTomorrow         0
# dtype: int64

# %%
#replacing null values in categorical variables with mode value
df1['WindGustDir'].fillna(df1['WindGustDir'].mode()[0], inplace=True)
df1['WindDir9am'].fillna(df1['WindDir9am'].mode()[0], inplace=True)
df1['WindDir3pm'].fillna(df1['WindDir3pm'].mode()[0], inplace=True)
df1['RainToday'].fillna(df1['RainToday'].mode()[0], inplace=True)
df1['RainTomorrow'].fillna(df1['RainTomorrow'].mode()[0], inplace=True)

# %%
#Count of null values in dataset
df1.isna().sum()
# Out:
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir          0
# WindGustSpeed     9270
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %%
# view the categorical variables

df1[categorical].head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0   Albury           W          W        WNW        No           No
# 1   Albury         WNW        NNW        WSW        No           No
# 2   Albury         WSW          W        WSW        No           No
# 3   Albury          NE         SE          E        No           No
# 4   Albury           W        ENE         NW        No           No

# %%
df1.RainTomorrow.value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
ll=pd.isnull(df["RainTomorrow"])
ll
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145455    False
# 145456    False
# 145457    False
# 145458    False
# 145459     True
# Name: RainTomorrow, Length: 145460, dtype: bool

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'Location'.'RainTomorrow','Date','WindDir9am',	'WindDir3pm',	'RainToday',	'RainTomorrow'
df1['Location']= label_encoder.fit_transform(df1['Location'])
df1['WindGustDir']= label_encoder.fit_transform(df1['WindGustDir'])
df1['WindDir9am']= label_encoder.fit_transform(df1['WindDir9am'])
df1['WindDir3pm']= label_encoder.fit_transform(df1['WindDir3pm'])
df1['RainToday']= label_encoder.fit_transform(df1['RainToday'])
df1['RainTomorrow']= label_encoder.fit_transform(df1['RainTomorrow'])

# %%
#Display data variables
df1
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0              2     13.4     22.9       0.6          NaN       NaN
# 1              2      7.4     25.1       0.0          NaN       NaN
# 2              2     12.9     25.7       0.0          NaN       NaN
# 3              2      9.2     28.0       0.0          NaN       NaN
# 4              2     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...       ...          ...       ...
# 145454        41      3.5     21.8       0.0          NaN       NaN
# 145455        41      2.8     23.4       0.0          NaN       NaN
# 145456        41      3.6     25.3       0.0          NaN       NaN
# 145457        41      5.4     26.9       0.0          NaN       NaN
# 145458        41      7.8     27.0       0.0          NaN       NaN
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# 0                13           44.0          13          14  ...         71.0
# 1                14           44.0           6          15  ...         44.0
# 2                15           46.0          13          15  ...         38.0
# 3                 4           24.0           9           0  ...         45.0
# 4                13           41.0           1           7  ...         82.0
# ...             ...            ...         ...         ...  ...          ...
# 145454            0           31.0           2           0  ...         59.0
# 145455            0           31.0           9           1  ...         51.0
# 145456            6           22.0           9           3  ...         56.0
# 145457            3           37.0           9          14  ...         53.0
# 145458            9           28.0          10           3  ...         51.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145454         27.0       1024.7       1021.2       NaN       NaN      9.4
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8          0             0
# 1          24.3          0             0
# 2          23.2          0             0
# 3          26.5          0             0
# 4          29.7          0             0
# ...         ...        ...           ...
# 145454     20.9          0             0
# 145455     22.4          0             0
# 145456     24.5          0             0
# 145457     26.1          0             0
# 145458     26.0          0             0
#
# [142193 rows x 22 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 145458
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       142193 non-null  int64
#  1   MinTemp        141556 non-null  float64
#  2   MaxTemp        141871 non-null  float64
#  3   Rainfall       140787 non-null  float64
#  4   Evaporation    81350 non-null   float64
#  5   Sunshine       74377 non-null   float64
#  6   WindGustDir    142193 non-null  int64
#  7   WindGustSpeed  132923 non-null  float64
#  8   WindDir9am     142193 non-null  int64
#  9   WindDir3pm     142193 non-null  int64
#  10  WindSpeed9am   140845 non-null  float64
#  11  WindSpeed3pm   139563 non-null  float64
#  12  Humidity9am    140419 non-null  float64
#  13  Humidity3pm    138583 non-null  float64
#  14  Pressure9am    128179 non-null  float64
#  15  Pressure3pm    128212 non-null  float64
#  16  Cloud9am       88536 non-null   float64
#  17  Cloud3pm       85099 non-null   float64
#  18  Temp9am        141289 non-null  float64
#  19  Temp3pm        139467 non-null  float64
#  20  RainToday      142193 non-null  int64
#  21  RainTomorrow   142193 non-null  int64
# dtypes: float64(16), int64(6)
# memory usage: 25.0 MB

# %%
#There is not null record in our data
df1.isnull().sum()
# Out:
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir          0
# WindGustSpeed     9270
# WindDir9am           0
# WindDir3pm           0
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday            0
# RainTomorrow         0
# dtype: int64

# %%
#filling the null values in numerical variable with median
df1 = df1.fillna(df1.median())

# %%
#Create new dataset and find null valuesdf2,isna().sum()
df2 = df[~df['RainTomorrow'].notna()]
df2
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 14       Albury      8.4     24.6       0.0          NaN       NaN
# 283      Albury      2.6      NaN       0.0          NaN       NaN
# 435      Albury     22.1     35.1       0.0          NaN       NaN
# 437      Albury     21.5     35.0       0.0          NaN       NaN
# 443      Albury     15.5     30.6       0.0          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 144955    Uluru     22.5     37.7       0.0          NaN       NaN
# 145091    Uluru     12.3     19.1       0.0          NaN       NaN
# 145092    Uluru     14.2     18.7       NaN          NaN       NaN
# 145335    Uluru     13.5      NaN       0.0          NaN       NaN
# 145459    Uluru     14.9      NaN       0.0          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 14             NaN            NaN          S        WNW  ...         57.0
# 283            NaN            NaN          E        WNW  ...         71.0
# 435            NaN            NaN        ENE         SW  ...         58.0
# 437            NaN            NaN        SSE          E  ...         76.0
# 443            NaN            NaN         SE        SSW  ...         66.0
# ...            ...            ...        ...        ...  ...          ...
# 144955          SE           50.0         SE        ESE  ...         22.0
# 145091         NaN            NaN        NaN        NaN  ...         79.0
# 145092         NaN            NaN          W        NaN  ...         81.0
# 145335         NaN            NaN        ENE         SW  ...         23.0
# 145459         NaN            NaN        ESE        ESE  ...         62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 14             32.0       1009.7       1008.7       NaN       NaN     15.9
# 283            55.0       1017.8       1017.6       NaN       6.0      9.7
# 435            37.0       1020.9       1017.8       NaN       1.0     26.9
# 437            35.0       1015.8       1010.3       NaN       8.0     24.2
# 443            30.0       1015.9       1013.8       NaN       NaN     19.4
# ...             ...          ...          ...       ...       ...      ...
# 144955         11.0       1012.6       1009.6       NaN       NaN     28.8
# 145091         62.0       1016.8       1014.1       8.0       8.0     15.6
# 145092         67.0       1015.2       1014.6       8.0       8.0     16.6
# 145335         11.0       1013.7       1008.4       NaN       NaN     25.2
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 14         23.5         No           NaN
# 283        14.3         No           NaN
# 435        33.5         No           NaN
# 437        33.1         No           NaN
# 443        30.0         No           NaN
# ...         ...        ...           ...
# 144955     37.2         No           NaN
# 145091     18.9         No           NaN
# 145092     17.5        NaN           NaN
# 145335     34.4         No           NaN
# 145459     20.9         No           NaN
#
# [3267 rows x 22 columns]

# %%
df.RainTomorrow.value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
df2.isna().sum()
# Out:
# Location            0
# MinTemp           848
# MaxTemp           939
# Rainfall         1855
# Evaporation      1947
# Sunshine         2019
# WindGustDir       996
# WindGustSpeed     993
# WindDir9am        553
# WindDir3pm        450
# WindSpeed9am      419
# WindSpeed3pm      432
# Humidity9am       880
# Humidity3pm       897
# Pressure9am      1051
# Pressure3pm      1047
# Cloud9am         2231
# Cloud3pm         2264
# Temp9am           863
# Temp3pm           883
# RainToday        1855
# RainTomorrow     3267
# dtype: int64

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
  
# Encode labels in column 'Location'.'RainTomorrow','Date','WindDir9am',	'WindDir3pm',	'RainToday',	'RainTomorrow'
df2['Location']= label_encoder.fit_transform(df2['Location'])
df2['WindGustDir']= label_encoder.fit_transform(df2['WindGustDir'])
df2['WindDir9am']= label_encoder.fit_transform(df2['WindDir9am'])
df2['WindDir3pm']= label_encoder.fit_transform(df2['WindDir3pm'])
df2['RainToday']= label_encoder.fit_transform(df2['RainToday'])
df2['RainTomorrow']= label_encoder.fit_transform(df2['RainTomorrow'])

# %%
#filling the null values in numerical variable
df2['MinTemp'] = df2['MinTemp'].fillna(df2['MinTemp'].median())
df2['MaxTemp'] = df2['MaxTemp'].fillna(df2['MaxTemp'].median())
df2['Rainfall'] = df2['Rainfall'].fillna(df2['Rainfall'].median())
df2['Evaporation'] = df2['Evaporation'].fillna(df2['Evaporation'].median())
df2['Sunshine'] = df2['Sunshine'].fillna(df2['Sunshine'].median())
df2['WindGustSpeed'] = df2['WindGustSpeed'].fillna(df2['WindGustSpeed'].median())
df2['WindSpeed9am'] = df2['WindSpeed9am'].fillna(df2['WindSpeed9am'].median())
df2['WindSpeed3pm'] = df2['WindSpeed3pm'].fillna(df2['WindSpeed3pm'].median())
df2['Humidity9am'] = df2['Humidity9am'].fillna(df2['Humidity9am'].median())
df2['Humidity3pm'] = df2['Humidity3pm'].fillna(df2['Humidity3pm'].median())
df2['Pressure9am'] = df2['Pressure9am'].fillna(df2['Pressure9am'].median())
df2['Pressure3pm'] = df2['Pressure3pm'].fillna(df2['Pressure3pm'].median())
df2['Cloud9am'] = df2['Cloud9am'].fillna(df2['Cloud9am'].median())
df2['Cloud3pm'] = df2['Cloud3pm'].fillna(df2['Cloud3pm'].median())
df2['Temp9am'] = df2['Temp9am'].fillna(df2['Temp9am'].median())
df2['Temp3pm'] = df2['Temp3pm'].fillna(df2['Temp3pm'].median())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3267 entries, 14 to 145459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       3267 non-null   int64
#  1   MinTemp        3267 non-null   float64
#  2   MaxTemp        3267 non-null   float64
#  3   Rainfall       3267 non-null   float64
#  4   Evaporation    3267 non-null   float64
#  5   Sunshine       3267 non-null   float64
#  6   WindGustDir    3267 non-null   int64
#  7   WindGustSpeed  3267 non-null   float64
#  8   WindDir9am     3267 non-null   int64
#  9   WindDir3pm     3267 non-null   int64
#  10  WindSpeed9am   3267 non-null   float64
#  11  WindSpeed3pm   3267 non-null   float64
#  12  Humidity9am    3267 non-null   float64
#  13  Humidity3pm    3267 non-null   float64
#  14  Pressure9am    3267 non-null   float64
#  15  Pressure3pm    3267 non-null   float64
#  16  Cloud9am       3267 non-null   float64
#  17  Cloud3pm       3267 non-null   float64
#  18  Temp9am        3267 non-null   float64
#  19  Temp3pm        3267 non-null   float64
#  20  RainToday      3267 non-null   int64
#  21  RainTomorrow   3267 non-null   int64
# dtypes: float64(16), int64(6)
# memory usage: 587.0 KB

# %%
from sklearn.utils.validation import indexable
X_train = df1.drop(['RainTomorrow'], axis=1)
y_train = df1['RainTomorrow']

print(X_train.shape)
print(y_train.shape)
# Out:
# (142193, 21)
# (142193,)

# %%
X_train
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0              2     13.4     22.9       0.6          4.8       8.5
# 1              2      7.4     25.1       0.0          4.8       8.5
# 2              2     12.9     25.7       0.0          4.8       8.5
# 3              2      9.2     28.0       0.0          4.8       8.5
# 4              2     17.5     32.3       1.0          4.8       8.5
# ...          ...      ...      ...       ...          ...       ...
# 145454        41      3.5     21.8       0.0          4.8       8.5
# 145455        41      2.8     23.4       0.0          4.8       8.5
# 145456        41      3.6     25.3       0.0          4.8       8.5
# 145457        41      5.4     26.9       0.0          4.8       8.5
# 145458        41      7.8     27.0       0.0          4.8       8.5
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# 0                13           44.0          13          14  ...          24.0
# 1                14           44.0           6          15  ...          22.0
# 2                15           46.0          13          15  ...          26.0
# 3                 4           24.0           9           0  ...           9.0
# 4                13           41.0           1           7  ...          20.0
# ...             ...            ...         ...         ...  ...           ...
# 145454            0           31.0           2           0  ...          13.0
# 145455            0           31.0           9           1  ...          11.0
# 145456            6           22.0           9           3  ...           9.0
# 145457            3           37.0           9          14  ...           9.0
# 145458            9           28.0          10           3  ...           7.0
#
#         Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  \
# 0              71.0         22.0       1007.7       1007.1       8.0
# 1              44.0         25.0       1010.6       1007.8       5.0
# 2              38.0         30.0       1007.6       1008.7       5.0
# 3              45.0         16.0       1017.6       1012.8       5.0
# 4              82.0         33.0       1010.8       1006.0       7.0
# ...             ...          ...          ...          ...       ...
# 145454         59.0         27.0       1024.7       1021.2       5.0
# 145455         51.0         24.0       1024.6       1020.3       5.0
# 145456         56.0         21.0       1023.5       1019.1       5.0
# 145457         53.0         24.0       1021.0       1016.8       5.0
# 145458         51.0         24.0       1019.4       1016.5       3.0
#
#         Cloud3pm  Temp9am  Temp3pm  RainToday
# 0            5.0     16.9     21.8          0
# 1            5.0     17.2     24.3          0
# 2            2.0     21.0     23.2          0
# 3            5.0     18.1     26.5          0
# 4            8.0     17.8     29.7          0
# ...          ...      ...      ...        ...
# 145454       5.0      9.4     20.9          0
# 145455       5.0     10.1     22.4          0
# 145456       5.0     10.9     24.5          0
# 145457       5.0     12.5     26.1          0
# 145458       2.0     15.1     26.0          0
#
# [142193 rows x 21 columns]

# %%
X_train.isna().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# dtype: int64

# %%
print(y_train.isna().sum())
X_train.isna().sum()
# Out:
# 0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# dtype: int64

# %%
X_train.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     13.4     22.9       0.6          4.8       8.5           13
# 1         2      7.4     25.1       0.0          4.8       8.5           14
# 2         2     12.9     25.7       0.0          4.8       8.5           15
# 3         2      9.2     28.0       0.0          4.8       8.5            4
# 4         2     17.5     32.3       1.0          4.8       8.5           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  Humidity9am  \
# 0           44.0          13          14  ...          24.0         71.0
# 1           44.0           6          15  ...          22.0         44.0
# 2           46.0          13          15  ...          26.0         38.0
# 3           24.0           9           0  ...           9.0         45.0
# 4           41.0           1           7  ...          20.0         82.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0         22.0       1007.7       1007.1       8.0       5.0     16.9
# 1         25.0       1010.6       1007.8       5.0       5.0     17.2
# 2         30.0       1007.6       1008.7       5.0       2.0     21.0
# 3         16.0       1017.6       1012.8       5.0       5.0     18.1
# 4         33.0       1010.8       1006.0       7.0       8.0     17.8
#
#    Temp3pm  RainToday
# 0     21.8          0
# 1     24.3          0
# 2     23.2          0
# 3     26.5          0
# 4     29.7          0
#
# [5 rows x 21 columns]

# %%
y_train
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 145454    0
# 145455    0
# 145456    0
# 145457    0
# 145458    0
# Name: RainTomorrow, Length: 142193, dtype: int64

# %%
df1.RainTomorrow.value_counts()
# Out:
# 0    110316
# 1     31877
# Name: RainTomorrow, dtype: int64

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)

# %%
x=X_train
y=y_train

# %%
y=np.array(y, dtype=np.int64)
x=np.array(x, dtype=np.int64)

# %%
oversample = SMOTE()
x, y = oversample.fit_resample(x, y)

# %%
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 110316, 1: 110316})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train,y_train, test_size=0.20, random_state=42)

# %%
sc_x = StandardScaler()
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_train.shape
# Out:
# (113754, 21, 1)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
X_test.shape
# Out:
# (28439, 21, 1)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        143975 non-null  float64
#  2   MaxTemp        144199 non-null  float64
#  3   Rainfall       142199 non-null  float64
#  4   Evaporation    82670 non-null   float64
#  5   Sunshine       75625 non-null   float64
#  6   WindGustDir    135134 non-null  object
#  7   WindGustSpeed  135197 non-null  float64
#  8   WindDir9am     134894 non-null  object
#  9   WindDir3pm     141232 non-null  object
#  10  WindSpeed9am   143693 non-null  float64
#  11  WindSpeed3pm   142398 non-null  float64
#  12  Humidity9am    142806 non-null  float64
#  13  Humidity3pm    140953 non-null  float64
#  14  Pressure9am    130395 non-null  float64
#  15  Pressure3pm    130432 non-null  float64
#  16  Cloud9am       89572 non-null   float64
#  17  Cloud3pm       86102 non-null   float64
#  18  Temp9am        143693 non-null  float64
#  19  Temp3pm        141851 non-null  float64
#  20  RainToday      142199 non-null  object
#  21  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(6)
# memory usage: 24.4+ MB

# %%
from keras.callbacks import EarlyStopping
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=5, verbose=1, mode='auto')

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(21,1), activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(LSTM(128,activation='relu', return_sequences=True))
model.add(Dropout(0.3))

model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))

model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss="binary_crossentropy", optimizer='adam', metrics=['accuracy'])

# %%
# training the model on training dataset
history = model.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=1000,
                    callbacks=[early],
                    validation_split=0.2)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 12s 107ms/step - loss: 0.6736 - accuracy: 0.6838 - val_loss: 0.5679 - val_accuracy: 0.7783
# Epoch 2/100
# 92/92 [==============================] - 9s 93ms/step - loss: 0.5630 - accuracy: 0.7709 - val_loss: 0.5329 - val_accuracy: 0.7783
# Epoch 3/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.5295 - accuracy: 0.7790 - val_loss: 0.5285 - val_accuracy: 0.7783
# Epoch 4/100
# 92/92 [==============================] - 9s 101ms/step - loss: 0.5203 - accuracy: 0.7806 - val_loss: 0.5254 - val_accuracy: 0.7782
# Epoch 5/100
# 92/92 [==============================] - 9s 95ms/step - loss: 0.5185 - accuracy: 0.7811 - val_loss: 0.5233 - val_accuracy: 0.7783
# Epoch 6/100
# 92/92 [==============================] - 8s 92ms/step - loss: 0.5136 - accuracy: 0.7826 - val_loss: 0.5129 - val_accuracy: 0.7784
# Epoch 7/100
# 92/92 [==============================] - 9s 92ms/step - loss: 0.5100 - accuracy: 0.7831 - val_loss: 0.5030 - val_accuracy: 0.7801
# Epoch 8/100
# 92/92 [==============================] - 9s 101ms/step - loss: 0.4994 - accuracy: 0.7851 - val_loss: 0.4891 - val_accuracy: 0.7883
# Epoch 9/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4981 - accuracy: 0.7861 - val_loss: 0.4868 - val_accuracy: 0.7845
# Epoch 10/100
# 92/92 [==============================] - 9s 94ms/step - loss: 0.4939 - accuracy: 0.7860 - val_loss: 0.4778 - val_accuracy: 0.7898
# Epoch 11/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4898 - accuracy: 0.7874 - val_loss: 0.4753 - val_accuracy: 0.7935
# Epoch 12/100
# 92/92 [==============================] - 8s 91ms/step - loss: 0.4833 - accuracy: 0.7895 - val_loss: 0.4781 - val_accuracy: 0.7973
# Epoch 13/100
# 92/92 [==============================] - 9s 94ms/step - loss: 0.4903 - accuracy: 0.7879 - val_loss: 0.4676 - val_accuracy: 0.7938
# Epoch 14/100
# 92/92 [==============================] - 8s 92ms/step - loss: 0.4802 - accuracy: 0.7905 - val_loss: 0.4582 - val_accuracy: 0.7968
# Epoch 15/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4704 - accuracy: 0.7941 - val_loss: 0.4679 - val_accuracy: 0.8008
# Epoch 16/100
# 92/92 [==============================] - 9s 93ms/step - loss: 0.4807 - accuracy: 0.7897 - val_loss: 0.4610 - val_accuracy: 0.7958
# Epoch 17/100
# 92/92 [==============================] - 8s 92ms/step - loss: 0.4924 - accuracy: 0.7845 - val_loss: 0.4665 - val_accuracy: 0.7947
# Epoch 18/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4686 - accuracy: 0.7939 - val_loss: 0.4447 - val_accuracy: 0.8054
# Epoch 19/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4623 - accuracy: 0.7975 - val_loss: 0.4405 - val_accuracy: 0.8070
# Epoch 20/100
# 92/92 [==============================] - 9s 95ms/step - loss: 0.4669 - accuracy: 0.7963 - val_loss: 0.4400 - val_accuracy: 0.8096
# Epoch 21/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4553 - accuracy: 0.8009 - val_loss: 0.4330 - val_accuracy: 0.8105
# Epoch 22/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4513 - accuracy: 0.8026 - val_loss: 0.4314 - val_accuracy: 0.8107
# Epoch 23/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4483 - accuracy: 0.8039 - val_loss: 0.4297 - val_accuracy: 0.8107
# Epoch 24/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4439 - accuracy: 0.8054 - val_loss: 0.4343 - val_accuracy: 0.8110
# Epoch 25/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4459 - accuracy: 0.8055 - val_loss: 0.4274 - val_accuracy: 0.8123
# Epoch 26/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4423 - accuracy: 0.8066 - val_loss: 0.4248 - val_accuracy: 0.8143
# Epoch 27/100
# 92/92 [==============================] - 8s 91ms/step - loss: 0.4391 - accuracy: 0.8076 - val_loss: 0.4191 - val_accuracy: 0.8161
# Epoch 28/100
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4360 - accuracy: 0.8081 - val_loss: 0.4180 - val_accuracy: 0.8159
# Epoch 29/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4340 - accuracy: 0.8089 - val_loss: 0.4158 - val_accuracy: 0.8167
# Epoch 30/100
# 92/92 [==============================] - 9s 95ms/step - loss: 0.4330 - accuracy: 0.8099 - val_loss: 0.4146 - val_accuracy: 0.8174
# Epoch 31/100
# 92/92 [==============================] - 9s 95ms/step - loss: 0.4311 - accuracy: 0.8102 - val_loss: 0.4158 - val_accuracy: 0.8167
# Epoch 32/100
# 92/92 [==============================] - 8s 91ms/step - loss: 0.4306 - accuracy: 0.8109 - val_loss: 0.4134 - val_accuracy: 0.8184
# Epoch 33/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4297 - accuracy: 0.8112 - val_loss: 0.4113 - val_accuracy: 0.8186
# Epoch 34/100
# 92/92 [==============================] - 9s 93ms/step - loss: 0.4274 - accuracy: 0.8120 - val_loss: 0.4172 - val_accuracy: 0.8171
# Epoch 35/100
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4406 - accuracy: 0.8075 - val_loss: 0.4155 - val_accuracy: 0.8175
# Epoch 36/100
# 92/92 [==============================] - 10s 104ms/step - loss: 0.4305 - accuracy: 0.8111 - val_loss: 0.4128 - val_accuracy: 0.8194
# Epoch 37/100
# 92/92 [==============================] - 9s 93ms/step - loss: 0.4267 - accuracy: 0.8124 - val_loss: 0.4103 - val_accuracy: 0.8193
# Epoch 38/100
# 92/92 [==============================] - 9s 92ms/step - loss: 0.4247 - accuracy: 0.8128 - val_loss: 0.4090 - val_accuracy: 0.8195
# Epoch 39/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4227 - accuracy: 0.8140 - val_loss: 0.4144 - val_accuracy: 0.8173
# Epoch 40/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4308 - accuracy: 0.8098 - val_loss: 0.4112 - val_accuracy: 0.8180
# Epoch 41/100
# 92/92 [==============================] - 9s 94ms/step - loss: 0.4229 - accuracy: 0.8135 - val_loss: 0.4110 - val_accuracy: 0.8199
# Epoch 42/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4338 - accuracy: 0.8097 - val_loss: 0.4119 - val_accuracy: 0.8195
# Epoch 43/100
# 92/92 [==============================] - 10s 108ms/step - loss: 0.4247 - accuracy: 0.8127 - val_loss: 0.4108 - val_accuracy: 0.8194
# Epoch 44/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4261 - accuracy: 0.8116 - val_loss: 0.4095 - val_accuracy: 0.8199
# Epoch 45/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4208 - accuracy: 0.8147 - val_loss: 0.4074 - val_accuracy: 0.8201
# Epoch 46/100
# 92/92 [==============================] - 10s 109ms/step - loss: 0.4199 - accuracy: 0.8150 - val_loss: 0.4064 - val_accuracy: 0.8208
# Epoch 47/100
# 92/92 [==============================] - 9s 102ms/step - loss: 0.4187 - accuracy: 0.8158 - val_loss: 0.4058 - val_accuracy: 0.8213
# Epoch 48/100
# 92/92 [==============================] - 9s 101ms/step - loss: 0.4185 - accuracy: 0.8157 - val_loss: 0.4060 - val_accuracy: 0.8219
# Epoch 49/100
# 92/92 [==============================] - 9s 94ms/step - loss: 0.4179 - accuracy: 0.8156 - val_loss: 0.4085 - val_accuracy: 0.8220
# Epoch 50/100
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4231 - accuracy: 0.8146 - val_loss: 0.4070 - val_accuracy: 0.8213
# Epoch 51/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4177 - accuracy: 0.8159 - val_loss: 0.4049 - val_accuracy: 0.8218
# Epoch 52/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4160 - accuracy: 0.8168 - val_loss: 0.4041 - val_accuracy: 0.8223
# Epoch 53/100
# 92/92 [==============================] - 10s 103ms/step - loss: 0.4154 - accuracy: 0.8171 - val_loss: 0.4031 - val_accuracy: 0.8228
# Epoch 54/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4150 - accuracy: 0.8172 - val_loss: 0.4042 - val_accuracy: 0.8220
# Epoch 55/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4194 - accuracy: 0.8151 - val_loss: 0.4058 - val_accuracy: 0.8217
# Epoch 56/100
# 92/92 [==============================] - 9s 96ms/step - loss: 0.4203 - accuracy: 0.8140 - val_loss: 0.4044 - val_accuracy: 0.8221
# Epoch 57/100
# 92/92 [==============================] - 10s 108ms/step - loss: 0.4151 - accuracy: 0.8169 - val_loss: 0.4036 - val_accuracy: 0.8218
# Epoch 58/100
# 92/92 [==============================] - 9s 101ms/step - loss: 0.4136 - accuracy: 0.8176 - val_loss: 0.4026 - val_accuracy: 0.8232
# Epoch 59/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4130 - accuracy: 0.8180 - val_loss: 0.4031 - val_accuracy: 0.8223
# Epoch 60/100
# 92/92 [==============================] - 10s 104ms/step - loss: 0.4212 - accuracy: 0.8141 - val_loss: 0.4046 - val_accuracy: 0.8219
# Epoch 61/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4157 - accuracy: 0.8169 - val_loss: 0.4035 - val_accuracy: 0.8224
# Epoch 62/100
# 92/92 [==============================] - 8s 91ms/step - loss: 0.4128 - accuracy: 0.8183 - val_loss: 0.4021 - val_accuracy: 0.8231
# Epoch 63/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4119 - accuracy: 0.8188 - val_loss: 0.4021 - val_accuracy: 0.8233
# Epoch 64/100
# 92/92 [==============================] - 10s 107ms/step - loss: 0.4119 - accuracy: 0.8186 - val_loss: 0.4024 - val_accuracy: 0.8234
# Epoch 65/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4116 - accuracy: 0.8189 - val_loss: 0.4022 - val_accuracy: 0.8230
# Epoch 66/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4143 - accuracy: 0.8186 - val_loss: 0.4019 - val_accuracy: 0.8239
# Epoch 67/100
# 92/92 [==============================] - 10s 105ms/step - loss: 0.4115 - accuracy: 0.8190 - val_loss: 0.4022 - val_accuracy: 0.8235
# Epoch 68/100
# 92/92 [==============================] - 9s 95ms/step - loss: 0.4101 - accuracy: 0.8195 - val_loss: 0.4015 - val_accuracy: 0.8239
# Epoch 69/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4099 - accuracy: 0.8198 - val_loss: 0.4003 - val_accuracy: 0.8246
# Epoch 70/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4087 - accuracy: 0.8201 - val_loss: 0.3998 - val_accuracy: 0.8244
# Epoch 71/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4100 - accuracy: 0.8196 - val_loss: 0.4007 - val_accuracy: 0.8241
# Epoch 72/100
# 92/92 [==============================] - 9s 97ms/step - loss: 0.4087 - accuracy: 0.8201 - val_loss: 0.4001 - val_accuracy: 0.8249
# Epoch 73/100
# 92/92 [==============================] - 9s 93ms/step - loss: 0.4082 - accuracy: 0.8203 - val_loss: 0.3992 - val_accuracy: 0.8249
# Epoch 74/100
# 92/92 [==============================] - 9s 100ms/step - loss: 0.4071 - accuracy: 0.8208 - val_loss: 0.4124 - val_accuracy: 0.8180
# Epoch 75/100
# 92/92 [==============================] - 9s 99ms/step - loss: 0.4151 - accuracy: 0.8169 - val_loss: 0.4018 - val_accuracy: 0.8235
# Epoch 76/100
# 92/92 [==============================] - 9s 98ms/step - loss: 0.4097 - accuracy: 0.8199 - val_loss: 0.3999 - val_accuracy: 0.8243
# Epoch 77/100
# 92/92 [==============================] - 10s 113ms/step - loss: 0.4080 - accuracy: 0.8204 - val_loss: 0.3990 - val_accuracy: 0.8246
# Epoch 78/100
# 92/92 [==============================] - 9s 103ms/step - loss: 0.4071 - accuracy: 0.8205 - val_loss: 0.3998 - val_accuracy: 0.8241
# Epoch 00078: early stopping

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history)

pd.DataFrame(history.history)[["accuracy", "val_accuracy"]].plot()
plt.title("Training Accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")

pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
